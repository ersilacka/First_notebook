# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# <h1>My Jupyter Notebook on IBM Watson Studio</h1>

# %% [markdown]
# <b>Ersi Lacka</b>
# Data Scientist

# %% [markdown]
# <i>I am interested in data science because I always was a curious type and wanted to find the answers to all the questions. Specially in the sales business world when I feel I can make a difference. </i>

# %% [markdown]
# <h3>The code below prints your name formated. </h3>

# %%
def your_name(name: str, last_name: str):
    print(name.capitalize()," ",last_name.capitalize())

your_name("ersi","lacka")
# Out:
# Ersi   Lacka

# %% [markdown]
# <p>Some of my favourite flowers are:</P>
# <ul><li>Roses</li> <li>Lilies</li><li>Orchides</li></ul>
#
# If you want to see some flowers <a href ="https://www.google.com/search?q=flowers&rlz=1C5CHFA_enGB1018GB1018&sxsrf=AJOqlzXvyL4MPtnuSGlkxfegZRQtySTTEQ:1677168819856&source=lnms&tbm=isch&sa=X&ved=2ahUKEwjnm_HdhKz9AhUBBMAKHdoSCL4Q_AUoAXoECAoQAw#imgrc=kynP2p55eMS7TM"> click here </a>
#
# <p>Or even better I am showing some flowers here</p> <img src="/Users/ersilacka/Downloads/Flower_poster_2.jpg">
